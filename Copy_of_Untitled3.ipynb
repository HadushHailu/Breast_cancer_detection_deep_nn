# %% [markdown]
# <a href="https://colab.research.google.com/github/HadushHailu/Breast_cancer_detection_deep_nn/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi 2>&1 | grep -i "cuda"

# %%
# !nvidia-smi
# Out:
# Wed May 22 01:49:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install retina-face

# %%
from retinaface import RetinaFace
import matplotlib.pyplot as plt

# %%
faces = RetinaFace.extract_faces(img_path = "./sample_data/ethiopians-compro.webp", align = False)
for face in faces:
  plt.imshow(face)
  plt.show()
